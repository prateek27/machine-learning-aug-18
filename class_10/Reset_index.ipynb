# %%
import pandas as pd

# %%
data = pd.read_csv("../class_08/titanic.csv")
data = data[10:50]
data
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# ...

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#     index  PassengerId  Survived  Pclass  \
# 0      10           11         1       3
# 1      11           12         1       1
# 2      12           13         0       3
# 3      13           14         0       3
# 4      14           15         0       3
# 5      15           16         1       2
# 6      16           17         0       3
# 7      17           18         1       2
# 8      18           19         0       3
# 9      19           20         1       3
# 10     20           21         0       2
# 11     21           22         1       2
# 12     22           23         1       3
# 13     23           24         1       1
# 14     24           25         0       3
# 15     25           26         1       3
# 16     26           27         0       3
# 17     27           28         0       1
# 18     28           29         1       3
# 19     29           30         0       3
# 20     30           31         0       1
# 21     31           32         1       1
# ...

# %%
data = pd.read_csv("../class_08/titanic.csv")
data = data[100:500]
data
# Out:
#      PassengerId  Survived  Pclass  \
# 100          101         0       3
# 101          102         0       3
# 102          103         0       1
# 103          104         0       3
# 104          105         0       3
# 105          106         0       3
# 106          107         1       3
# 107          108         1       3
# 108          109         0       3
# 109          110         1       3
# 110          111         0       1
# 111          112         0       3
# 112          113         0       3
# 113          114         0       3
# 114          115         0       3
# 115          116         0       3
# 116          117         0       3
# 117          118         0       2
# 118          119         0       1
# 119          120         0       3
# 120          121         0       2
# 121          122         0       3
# 122          123         0       2
# 123          124         1       2
# 124          125         0       1
# ...

# %%
data.reset_index(drop=True,inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            101         0       3
# 1            102         0       3
# 2            103         0       1
# 3            104         0       3
# 4            105         0       3
# 5            106         0       3
# 6            107         1       3
# 7            108         1       3
# 8            109         0       3
# 9            110         1       3
# 10           111         0       1
# 11           112         0       3
# 12           113         0       3
# 13           114         0       3
# 14           115         0       3
# 15           116         0       3
# 16           117         0       3
# 17           118         0       2
# 18           119         0       1
# 19           120         0       3
# 20           121         0       2
# 21           122         0       3
# 22           123         0       2
# 23           124         1       2
# 24           125         0       1
# ...
